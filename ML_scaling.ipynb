# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
k=pd.read_csv('loan_data_set.csv')

# %%
k
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
k.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
k.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
ss.fit(k[['ApplicantIncome']])
# Out:
# StandardScaler()

# %%
ss.transform(k[['ApplicantIncome']])
# Out:
# array([[ 7.29908229e-02],
#        [-1.34411954e-01],
#        [-3.93747337e-01],
#        [-4.62062470e-01],
#        [ 9.77284368e-02],
#        [ 2.21831139e-03],
#        [-5.03018784e-01],
#        [-3.87849628e-01],
#        [-2.28939128e-01],
#        [ 1.21845703e+00],
#        [-3.60982286e-01],
#        [-4.75659966e-01],
#        [-3.81788093e-01],
#        [-5.81654908e-01],
#        [-6.72414101e-01],
#        [-7.42880841e-02],
#        [-2.96107483e-01],
#        [-3.10196456e-01],
#        [-8.46090753e-02],
#        [-4.59277440e-01],
#        [ 3.69678365e-01],
#        [ 9.03563002e-02],
#        [-4.59277440e-01],
#        [-3.33951118e-01],
#        [-2.76284627e-01],
#        [ 6.80946355e-01],
#        [-4.26676214e-01],
#        [-1.92897571e-01],
#        [-6.48987089e-01],
#        [-2.70878394e-01],
#        [-2.02727086e-01],
#        [-3.66388519e-01],
#        [-1.16555001e-01],
#        [-3.11834708e-01],
#        [ 1.16259261e+00],
# ...

# %%
t['ApplicantIncome_new']=k['ApplicantIncome_new']=pd.DataFrame(ss.transform(k[['ApplicantIncome']]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t['ApplicantIncome_new']=k['ApplicantIncome_new']=pd.DataFrame(ss.transform(k[['ApplicantIncome']]))
#
# NameError: name 't' is not defined

# %%
t
# Out:
#             0  ApplicantIncome_new
# 0    0.072991             0.072991
# 1   -0.134412            -0.134412
# 2   -0.393747            -0.393747
# 3   -0.462062            -0.462062
# 4    0.097728             0.097728
# ..        ...                  ...
# 609 -0.410130            -0.410130
# 610 -0.212557            -0.212557
# 611  0.437174             0.437174
# 612  0.357064             0.357064
# 613 -0.134412            -0.134412
#
# [614 rows x 2 columns]

# %%
sns.displot(data=t,x='ApplicantIncome_new')

# %%
u=k['ApplicantIncome']

# %%
u
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
sns.boxplot(data=k,x='ApplicantIncome')
plt.subplot(1,2,2)
sns.boxplot(data=t,x='ApplicantIncome_new')
plt.show()

# %%
k
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
k.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 614, dtype: bool
